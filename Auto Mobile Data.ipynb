# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\vikas\\OneDrive\\Desktop\\Iota Notes\\Automobile_data.csv")

# %%
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %% [markdown]
# # 1. what is the average price and average mileage for convertible cars

# %%
convertable_cars = df[df['body-style'] == 'convertible']

# %%
average_price = convertable_cars['price'].mean()
average_mileage = convertable_cars['average-mileage'].mean()

# %%
df1 = pd.DataFrame({
    'Average Price': [average_price],
    'Average Mileage': [average_mileage]
})

# %%
df1
# Out:
#    Average Price  Average Mileage
# 0        22341.0        19.666667

# %% [markdown]
# # 2. Sort cars by company and price in decending order

# %%
df2 = df.sort_values(['company', 'price'] ,ascending= False,ignore_index=True)[['company', 'price']]

# %%
df2 = pd.DataFrame(df2)

# %%
df2
# Out:
#         company    price
# 0         volvo  13415.0
# 1         volvo  12940.0
# 2    volkswagen   9995.0
# 3    volkswagen   7995.0
# 4    volkswagen   7975.0
# ..          ...      ...
# 56         audi  15250.0
# 57         audi  13950.0
# 58  alfa-romero  16500.0
# 59  alfa-romero  16500.0
# 60  alfa-romero  13495.0
#
# [61 rows x 2 columns]

# %% [markdown]
# # 3. Save data for 'Toyota' separately

# %%
toyota_cars = df[df['company'] == 'Toyota']
df3 = toyota_cars.to_csv('toyota_cars.csv', index=False)

# %% [markdown]
# # 4. which company is producing most expensive car?

# %%
df4 = df.groupby('company')['price'].max().nlargest(1)

# %%
df4 = pd.DataFrame(df4)

# %%
df4
# Out:
#                  price
# company
# mercedes-benz  45400.0

# %% [markdown]
# # 5. Name the cars on basis of maximum length, highest wheelbase, maximum horsepower

# %%
df5 = df.groupby('company')['length','wheel-base','horsepower'].max()
# Out:
# C:\Users\vikas\AppData\Local\Temp\ipykernel_17816\1822934934.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df5 = df.groupby('company')['length','wheel-base','horsepower'].max()

# %%
df5 = pd.DataFrame(df5)

# %%
df5
# Out:
#                length  wheel-base  horsepower
# company
# alfa-romero     171.2        94.5         154
# audi            192.7       105.8         115
# bmw             197.0       110.0         182
# chevrolet       158.8        94.5          70
# dodge           157.3        93.7          68
# honda           175.4        96.5         101
# isuzu           170.7        94.5          78
# jaguar          199.6       113.0         262
# mazda           175.0       104.9         101
# mercedes-benz   208.1       120.9         184
# mitsubishi      172.4        96.3          88
# nissan          184.6       100.4         152
# porsche         175.7        98.4         288
# toyota          187.8       104.5         156
# volkswagen      171.7        97.3         100
# volvo           188.8       104.3         114

# %% [markdown]
# # 6. company wise average price of cars and order them in decending order

# %%
df6 = df.groupby('company')['price'].mean().sort_values(ascending=False)

# %%
df6 = pd.DataFrame(df6)

# %%
df6
# Out:
#                       price
# company
# porsche        35528.000000
# mercedes-benz  35040.000000
# jaguar         34600.000000
# bmw            27213.333333
# audi           16392.500000
# alfa-romero    15498.333333
# volvo          13177.500000
# honda          10195.000000
# mazda           9654.800000
# volkswagen      8435.000000
# nissan          8289.000000
# toyota          8216.857143
# isuzu           6785.000000
# mitsubishi      6689.000000
# dodge           6303.000000
# chevrolet       6007.000000

# %% [markdown]
# # 7. create a column named: "decision", If wheel-base is less than 100 and length is less than 175 then "don't buy" else "buy"

# %%
df7 = df['decision'] = np.where((df['wheel-base'] < 100) & (df['length'] < 175) ,'don\'t buy','buy')

# %%
df7 = pd.DataFrame(df)

# %%
df7
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price   decision
# 0              four         111               21  13495.0  don't buy
# ...

# %% [markdown]
# # 8. Select only cars whose decision is "buy"; find average price based on company of car

# %%
buy_cars = df.groupby('decision').get_group('buy')

# %%
df8 = average_price = buy_cars.groupby('company')['price'].mean()

# %%
df8 = pd.DataFrame(df8)

# %%
df8
# Out:
#                       price
# company
# audi           16392.500000
# bmw            27213.333333
# honda          12945.000000
# jaguar         34600.000000
# mazda          18344.000000
# mercedes-benz  35040.000000
# nissan         13499.000000
# porsche                 NaN
# toyota         15750.000000
# volvo          13177.500000

# %% [markdown]
# # Create a single excel file to save all the outputs generated above in different subsheets. Email final output file and your python code (.ipynb) file to ranotiyahemant@gmail.com

# %%
import pandas as pd

# %%
path = 'C:\\Users\\vikas\\OneDrive\\Desktop\\Iota Notes\\Auto_mobile_data.xlsx'

with pd.ExcelWriter(path) as engine:
    
    df1.to_excel(excel_writer=engine,sheet_name="Average_convertable_car")
    df2.to_excel(excel_writer=engine,sheet_name="sort_car_company")
    df4.to_excel(excel_writer=engine,sheet_name='Most_expensive_car')
    df5.to_excel(excel_writer=engine,sheet_name="Car_on_basis")
    df6.to_excel(excel_writer=engine,sheet_name="Companywise_average")
    df7.to_excel(excel_writer=engine,sheet_name="Column_name_decision") 
    df8.to_excel(excel_writer=engine,sheet_name="Average_car_price")
